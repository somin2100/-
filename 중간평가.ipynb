# %% [markdown]
# <a href="https://colab.research.google.com/github/somin2100/-/blob/main/%EC%A4%91%EA%B0%84%ED%8F%89%EA%B0%80.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 중간평가

# %%
#글자깨짐 문제 수정을 위해 다음의 코드 실행 
#단계 1: 폰트 설치
import matplotlib.font_manager as fm

# !apt-get -qq -y install fonts-nanum > /dev/null
fontpath = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'
font = fm.FontProperties(fname=fontpath, size=9)
fm._rebuild()

# %%
# 단계 2: 런타임 재시작
import os
os.kill(os.getpid(), 9)

# %%
# 단계 3: 한글 폰트 설정
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.font_manager as fm

# 마이너스 표시 문제
mpl.rcParams['axes.unicode_minus'] = False
	
# 한글 폰트 설정
path = '/usr/share/fonts/truetype/nanum/NanumGothicBold.ttf'
font_name = fm.FontProperties(fname=path, size=18).get_name()
plt.rc('font', family=font_name)
fm._rebuild()

# %%
import csv
f=open('age.csv')
data=csv.reader(f)
result=[]
name=input('인구구조가 알고 싶은 지역의 이름')

for row in data:
  if name in row[0]:
    for i in row[3:]:
      result.append(int(i.replace(',','')))


plt.style.use('ggplot')
plt.title(name+'지역의 인구구조')
plt.plot(result)   
plt.show()
# Out:
# 인구구조가 알고 싶은 지역의 이름평촌

# %%
import csv
f=open('gender.csv')
data=csv.reader(f)
m=[] 
f=[] 
m2=[] 
name=input('인구구조가 알고 싶은 지역의 이름: ')

for row in data:
  if name in row[0]:
    for i in row[3:104]:
      m.append(-int(i.replace(',','')))
      m2.append(int(i.replace(',','')))
    for i in row[106:]:
      f.append(int(i.replace(',','')))

import matplotlib.pyplot as plt
plt.title(name+'지역의 남녀 인구 성별 분포')
plt.barh(range(101),m, label='남성')
plt.barh(range(101),f, label='여성')
plt.show()
# Out:
# 인구구조가 알고 싶은 지역의 이름: 평촌

# %%
import csv
import math
f=open('gender.csv')
data=csv.reader(f)
m=[]
f=[]
size=[]
name=input('궁금한 동네를 입력해주세요 : ')
for row in data:
  if name in row[0]:
    for i in range(3,104):
           m.append(int(row[i]))
           f.append(int(row[i+103]))
           size.append(math.sqrt(int(row[i])+int(row[i+103])))
    break
import matplotlib.pyplot as plot
plt.style.use('ggplot')
plt.title(name+' 지역의 성별 인구 그래프')
plt.scatter(m2,f, c=range(101), alpha=0.5, cmap='jet') 
plt.colorbar()
plt.plot(range(max(m2)), range(max(m2)), 'g') 
plt.xlabel('남성인구수')
plt.ylabel('여성인구수')
plt.show()
# Out:
# 궁금한 동네를 입력해주세요 : 평촌
